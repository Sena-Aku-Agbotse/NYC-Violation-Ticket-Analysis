# %%
#Load Data
import pandas as pd
data = pd.read_excel('nyc-violation-ticket - Copy.xlsx')
ny_violations = pd.DataFrame(data)
ny_violations
# Out:
#        Summons Number Plate ID Registration State Plate Type Issue Date  \
# 0          4714702166  KGK6659                 NY        PAS 2020-11-12
# 1          8793684599  L5232HY                 TN        PAS 2020-09-14
# 2          8864757053   BPMN76                 FL        PAS 2020-11-25
# 3          8778326047  57387MJ                 NY        COM 2020-08-20
# 4          4706640702   M81KFJ                 NJ        PAS 2020-09-09
# ...               ...      ...                ...        ...        ...
# 49995      4014245755  JPN4910                 NY        PAS 2020-06-25
# 49996      8794437506   174ZYG                 CT        PAS 2020-08-25
# 49997      8849769581  HES6895                 NY        PAS 2020-11-03
# 49998      8755448173  63035MN                 NY        COM 2020-08-19
# 49999      8581527528  AW74165                 CT        PAS 2020-08-06
#
#        Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# ...

# %%
#Finding the most common violations
common_violations = data['Violation Description'].value_counts()
common_violations
# Out:
# Violation Description
# PHTO SCHOOL ZN SPEED VIOLATION    14422
# FAILURE TO STOP AT RED LIGHT       1692
# BUS LANE VIOLATION                 1435
# 21-No Parking (street clean)        814
# 38-Failure to Dsplay Meter Rec      707
#                                   ...
# 49-Excavation (obstruct traff)        1
# 06-Nighttime PKG (Trailer)            1
# 08-Engine Idling (PAS)                1
# 87-Fraudulent Permit Use              1
# 01-No Intercity Pmt Displ             1
# Name: count, Length: 73, dtype: int64

# %%
#Finding the sum of missing values
data.isna().sum()
# Out:
# Summons Number                           0
# Plate ID                                 0
# Registration State                       0
# Plate Type                               0
# Issue Date                               0
# Violation Code                           0
# Vehicle Body Type                      145
# Vehicle Make                           136
# Issuing Agency                           0
# Street Code1                             0
# Street Code2                             0
# Street Code3                             0
# Vehicle Expiration Date                  0
# Violation Location                   17893
# Violation Precinct                       0
# Issuer Precinct                          0
# Issuer Code                              0
# Issuer Command                       17857
# Issuer Squad                         17857
# Violation Time                           1
# Time First Observed                  48111
# Violation County                       117
# ...

# %%
#Handling missing values in the dataset
# Determine the missing values per column before trimming
missing_values = ny_violations.isna().sum()
 
# Remove rows with any missing values
ny1_violation = ny_violations.dropna()
 
# Determine the missing values per column in the Data Frame after trimming
missing_values1 = ny1_violation.isna().sum()


ny1_violation
print("Missing values in each column before trimming:")
print(missing_values)
print()
 
# Print Info of missing values after pruning Data Frame
print("Missing values in each column after trimming:")
print(missing_values1)
print()
 
ny1_violation
# Out:
# Missing values in each column before trimming:
# Summons Number                           0
# Plate ID                                 0
# Registration State                       0
# Plate Type                               0
# Issue Date                               0
# Violation Code                           0
# Vehicle Body Type                      145
# Vehicle Make                           136
# Issuing Agency                           0
# Street Code1                             0
# Street Code2                             0
# Street Code3                             0
# Vehicle Expiration Date                  0
# Violation Location                   17893
# Violation Precinct                       0
# Issuer Precinct                          0
# Issuer Code                              0
# Issuer Command                       17857
# Issuer Squad                         17857
# Violation Time                           1
# Time First Observed                  48111
# ...

# %%
#Average fine amounts
avg_fine_by_violations

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 'Issue Date' is already in dataframe format
 
# Resample data to get monthly violation counts
monthly_violations = data.resample('M').size()
 
# Plot monthly violation counts
plt.figure(figsize=(10, 6))
monthly_violations.plot(kind='line', marker='o', color='b')
plt.title('Monthly Violation Counts Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Violations')
plt.grid(True)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_23380\4121436226.py:11: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_violations = data.resample('M').size()
